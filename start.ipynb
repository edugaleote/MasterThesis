# %%
import pandas as pd

# %%
nciALMANAC=pd.read_csv('ComboDrugGrowth_Nov2017.csv')
# Out:
# /Users/edugaleote/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3526: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
nciALMANAC
# Out:
#          COMBODRUGSEQ SCREENER                STUDY    TESTDATE        PLATE  \
# 0              260496       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 1              260497       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 2              260498       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 3              260499       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 4              260500       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# ...               ...      ...                  ...         ...          ...
# 3686470       5732421       1A             0903CB75  03/02/2009          322
# 3686471       5732422       1A             0903CB75  03/02/2009          322
# 3686472       5732423       1A             0903CB75  03/02/2009          322
# 3686473       5732424       1A             0903CB75  03/02/2009          322
# 3686474       5732425       1A             0903CB75  03/02/2009          322
#
# ...

# %%
drug_data=pd.read_csv('nsc_smiles.csv')

# %%
drug_data
# Out:
#            NSC                                             SMILES
# 0            1                                  CC1=CC(=O)C=CC1=O
# 1            2                     S(Sc1nc2ccccc2s1)c3nc4ccccc4s3
# 2            3            Oc1c(Cl)cc(cc1[N+](=O)[O-])[N+](=O)[O-]
# 3            4                             Nc1ncc(s1)[N+](=O)[O-]
# 4            5                      Nc1ccc2C(=O)c3ccccc3C(=O)c2c1
# ...        ...                                                ...
# 319913  852727  C[S@@](=N)(=O)c1ccc(cc1)C(=O)Nc2cc(ccc2N)c3ccc...
# 319914  852740  C[C@H]1CN(C)CCN1c2cc(cc(n2)c3noc(n3)[C@@]4(C)C...
# 319915  852741  CN(c1ncccc1CNc2ccnc(n2)c3nc4c(F)c(Cl)ccc4[nH]3...
# 319916  852742     CS(=O)(=O)c1ccc(cc1c2cc(O)c3c(F)cc(F)cc3n2)C#N
# 319917  852754   CN(c1ccccc1)c2ccc3[C@H](CNc4cnccc4C(=O)O)CCCc3c2
#
# [319918 rows x 2 columns]
